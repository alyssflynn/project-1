# %%
# Importing Dependencies
import requests
import csv
import pandas as pd

# %%
# Reading data 
# Retrieved data from https://aqs.epa.gov/aqsweb/airdata/download_files.html#Annual
# Data taken for a period of 10years from 2007 to 2017

def read_data(filepath):
    return pd.read_csv(filepath)

aqi_2007_df = read_data("raw_data/annual_aqi_by_county_2007.csv")
aqi_2008_df = read_data("raw_data/annual_aqi_by_county_2008.csv")
aqi_2009_df = read_data("raw_data/annual_aqi_by_county_2009.csv")
aqi_2010_df = read_data("raw_data/annual_aqi_by_county_2010.csv")
aqi_2011_df = read_data("raw_data/annual_aqi_by_county_2011.csv")
aqi_2012_df = read_data("raw_data/annual_aqi_by_county_2012.csv")
aqi_2013_df = read_data("raw_data/annual_aqi_by_county_2013.csv")
aqi_2014_df = read_data("raw_data/annual_aqi_by_county_2014.csv")
aqi_2015_df = read_data("raw_data/annual_aqi_by_county_2015.csv")
aqi_2016_df = read_data("raw_data/annual_aqi_by_county_2016.csv")
aqi_2017_df = read_data("raw_data/annual_aqi_by_county_2017.csv")

# %%
# Concatenating the Air Quality data
aqi_2007_to_2017_data = pd.concat([aqi_2007_df, aqi_2008_df, aqi_2009_df, aqi_2010_df,
                                   aqi_2011_df, aqi_2012_df, aqi_2013_df, aqi_2014_df,
                                   aqi_2015_df, aqi_2016_df, aqi_2017_df])

# Retrieving specific columns related to the AQI data
columns = ['State', 'County', 'Year', 'Days with AQI', 'Max AQI',
       '90th Percentile AQI', 'Median AQI', 'Days CO', 'Days NO2',
       'Days Ozone', 'Days SO2', 'Days PM2.5', 'Days PM10']
aqi_2007_to_2017_data =  aqi_2007_to_2017_data[columns]

# %%
aqi_2007_to_2017_data
# Out:
#           State                 County  Year  Days with AQI  Max AQI  \
# 0       Alabama                Baldwin  2007            269      154
# 1       Alabama                   Clay  2007            283      166
# 2       Alabama                Colbert  2007            324      122
# 3       Alabama                 DeKalb  2007            108      116
# 4       Alabama                 Elmore  2007            244      151
# 5       Alabama               Escambia  2007            107      137
# 6       Alabama                 Etowah  2007            323      145
# 7       Alabama                Houston  2007            276      158
# 8       Alabama                Jackson  2007            273      120
# 9       Alabama              Jefferson  2007            365      203
# 10      Alabama               Lawrence  2007            282      156
# 11      Alabama                Madison  2007            364      182
# 12      Alabama                 Mobile  2007            359      164
# ...
