# %% [markdown]
# # Data Exploration

# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from config import state_abbrev, reverse_state_abbrev, state_codes

import plotly.offline as py
import plotly.graph_objs as go
import plotly.figure_factory as ff
py.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Read in clean datasets
county_aqi_1980_2018 = pd.read_csv('clean_data/county_aqi_1980_2018.csv', index_col=0)
county_cancer_trends = pd.read_csv('clean_data/county_cancer_trends.csv', index_col=0)
state_cancer_1998_2014 = pd.read_csv('clean_data/state_cancer_1998_2014.csv', index_col=0)

# %%
county_aqi_1980_2018.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  alabama  autauga  1980            179        122             35
# 1  alabama  autauga  1981            357        289             49
# 2  alabama  autauga  1982            245        203             36
# 3  alabama  autauga  1989             63         54              9
# 4  alabama  autauga  1990            266        183             64
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                   18               4                    0
# 1                                   15               4                    0
# 2                                    5               0                    1
# 3                                    0               0                    0
# 4                                   18               1                    0
#
#    Hazardous Days       ...         State Abbreviation  FIPS  State FIPS Code  \
# ...

# %%
county_cancer_trends.head()
# Out:
#                            Geography   FIPS  \
# 1        Union County, Florida(6,10)  12125
# 2       Owsley County, Kentucky(7,8)  21189
# 3     McCreary County, Kentucky(7,8)  21147
# 4  North Slope Borough, Alaska(6,10)   2185
# 5       Powell County, Kentucky(7,8)  21197
#
#   Met Healthy People Objective of ***?  \
# 1                                  ***
# 2                                  ***
# 3                                  ***
# 4                                  ***
# 5                                  ***
#
#   Age-Adjusted Incidence Rate() - cases per 100,000  \
# 1                                              215.1
# 2                                              179.7
# 3                                              154.1
# 4                                              150.8
# 5                                              140.9
#
#    Lower 95% Confidence Interval  Upper 95% Confidence Interval  \
# ...

# %%
state_cancer_1998_2014.head()
# Out:
#          State State Abbreviation  Year  Year Code  \
# 0  Connecticut                 CT  1999       1999
# 1  Connecticut                 CT  2000       2000
# 2  Connecticut                 CT  2001       2001
# 3  Connecticut                 CT  2002       2002
# 4  Connecticut                 CT  2003       2003
#
#                          Cancer Sites Cancer Sites Code  Count
# 0  All Invasive Cancer Sites Combined                 0  18694
# 1  All Invasive Cancer Sites Combined                 0  19200
# 2  All Invasive Cancer Sites Combined                 0  19626
# 3  All Invasive Cancer Sites Combined                 0  19570
# 4  All Invasive Cancer Sites Combined                 0  19516

# %%
values = merged_data['2017 Estimate'].tolist()
fips = merged_data['FIPS'].tolist()

# # colorscale = ["#ff0000","#ff9900","#ffff00","#ccff33","#33cc33", "#bfbfbf"]
# colorscale = ["#bfbfbf","#ff0000","#ff9900","#ffff00","#33cc33", "#bfbfbf"]
colorscale = [
    'rgb(193, 193, 193)',
    'rgb(239,239,239)',
    'rgb(195, 196, 222)',
    'rgb(144,148,194)',
    'rgb(101,104,168)',
    'rgb(65, 53, 132)'
]
# endpts = list(np.mgrid[0:max(values):5j])
binning_endpoints=[14348, 63983, 134827, 426762, 2081313]

fig = ff.create_choropleth(
    fips=fips, values=values, scope=['usa'],
    binning_endpoints = binning_endpoints,colorscale=colorscale,
    show_state_data=False,
    county_outline={'color': 'rgb(0,0,0)', 'width': 0.5},
    show_hover=True, centroid_marker={'opacity': 0},
    asp=2.9, title='USA County Population',
    legend_title='Population'
)
py.iplot(fig, filename='choropleth_full_usa')
